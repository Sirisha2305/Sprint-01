# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.listdir(r'C:\Users\Nanditha M\Desktop\goolge play store analysis')
# Out:
# ['Google-Playstore.csv']

# %%
data=pd.read_csv(r'C:\Users\Nanditha M\Desktop\goolge play store analysis\Google-Playstore.csv')
print(data)
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
# 1.DISPLAY TOP 5 ROWS OF THE DATASET
data.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
# 1(a)IF WE WANT SPECIFIC NUMBER OF ROWS MENTION THE NUMBER OF ROWS TO DISPLAY FROM THE TOP OF THE TABLE
data.head(3)
# Out:
#               App Name                      App Id      Category  Rating  \
# 0              Gakondo         com.ishakwe.gakondo     Adventure     0.0
# 1  Ampere Battery Info  com.webserveis.batteryinfo         Tools     4.4
# 2               Vibook        com.doantiepvien.crm  Productivity     0.0
#
#    Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0           0.0      10+              10.0                15  True    0.0
# 1          64.0   5,000+            5000.0              7662  True    0.0
# 2           0.0      50+              50.0                58  True    0.0
#
#    ...                Developer Website         Developer Email      Released  \
# 0  ...      https://beniyizibyose.tk/#/  jean21101999@gmail.com  Feb 26, 2020
# 1  ...  https://webserveis.netlify.app/    webserveis@gmail.com  May 21, 2020
# 2  ...                              NaN     vnacrewit@gmail.com   Aug 9, 2019
#
#    Last Updated Content Rating  \
# ...

# %%
#2.DISPLYING THE BOTTOM 5 ROWS OF THE DATASET
data.tail()
# Out:
#                              App Name                                App Id  \
# 2312939                      大俠客—熱血歸來                         com.rxsj.ssjj
# 2312940                    ORU Online              com.threedream.oruonline
# 2312941                Data Structure  datastructure.appoworld.datastucture
# 2312942                   Devi Suktam                     ishan.devi.suktam
# 2312943  Biliyor Musun - Sonsuz Yarış             com.yyazilim.biliyormusun
#
#               Category  Rating  Rating Count  Installs  Minimum Installs  \
# 2312939   Role Playing     4.3       16775.0  100,000+          100000.0
# 2312940      Education     0.0           0.0      100+             100.0
# 2312941      Education     0.0           0.0      100+             100.0
# 2312942  Music & Audio     3.5           8.0    1,000+            1000.0
# 2312943         Trivia     5.0          12.0      100+             100.0
#
#          Maximum Installs  Free  Price  ...  \
# ...

# %%
#2(a)IF WE WANT SPECIFIC NUMBER OF ROWS MENTION THE NUMBER OF ROWS TO DISPLAY FROM THE BOTTOM OF THE TABLE
data.tail(8)
# Out:
#                                  App Name  \
# 2312936                 Engineers Careers
# 2312937  STMIK Mercusuar - Aditya Rachman
# 2312938       Lero TOEFL Recorder + Timer
# 2312939                          大俠客—熱血歸來
# 2312940                        ORU Online
# 2312941                    Data Structure
# 2312942                       Devi Suktam
# 2312943      Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 2312936               com.eventapps.eventapps       Business     0.0
# 2312937          com.aplikasi.datapribadiadit      Education     0.0
# 2312938                        com.toefltimer      Education     3.4
# 2312939                         com.rxsj.ssjj   Role Playing     4.3
# 2312940              com.threedream.oruonline      Education     0.0
# 2312941  datastructure.appoworld.datastucture      Education     0.0
# 2312942                     ishan.devi.suktam  Music & Audio     3.5
# ...

# %%
#3.FINDING THE SHAPE OF OUR DATASET(NUMBER OF ROWS AND NUMBER OF COLUMNS)
data.shape
# Out:
# (2312944, 24)

# %%
#3(a)DISPLYING IN PROPER MANNER
print("Number of rows:",data.shape[0])
print("number of columns:",data.shape[1])
# Out:
# Number of rows: 2312944
# number of columns: 24

# %%
#4.GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPES OF EACH COLUMN AND MEMORY REQUIREMENT
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
#5.GETTING THE OVERALL STATISTICS ABOUT THE DATASET
data.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
#5(a)IF WE WANT STATISTICS FOR ALL THE COLUMNS
data.describe(include='all')
# Out:
#            App Name                     App Id   Category        Rating  \
# count       2312939                    2312944    2312944  2.290061e+06
# unique      2177943                    2312944         48           NaN
# top     Tic Tac Toe  com.yyazilim.biliyormusun  Education           NaN
# freq            382                          1     241090           NaN
# mean            NaN                        NaN        NaN  2.203152e+00
# std             NaN                        NaN        NaN  2.106223e+00
# min             NaN                        NaN        NaN  0.000000e+00
# 25%             NaN                        NaN        NaN  0.000000e+00
# 50%             NaN                        NaN        NaN  2.900000e+00
# 75%             NaN                        NaN        NaN  4.300000e+00
# max             NaN                        NaN        NaN  5.000000e+00
#
#         Rating Count Installs  Minimum Installs  Maximum Installs     Free  \
# ...

# %%
#6.TOTAL NUMBER OF APP TITLES CONTAIN DATASTRUCTURES
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#6(a)performing function on app column
data['App Name']
# Out:
# 0                                                    Gakondo
# 1                                        Ampere Battery Info
# 2                                                     Vibook
# 3          Smart City Trichy Public Service Vehicles 17UC...
# 4                                                    GROW.me
#                                  ...
# 2312939                                             大俠客—熱血歸來
# 2312940                                           ORU Online
# 2312941                                       Data Structure
# 2312942                                          Devi Suktam
# 2312943                         Biliyor Musun - Sonsuz Yarış
# Name: App Name, Length: 2312944, dtype: object

# %%
#6(b) HAVING ATROLOGY WORD IN THE TABLE
data['App Name'].str.contains('Data Structure')
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2312939    False
# 2312940    False
# 2312941     True
# 2312942    False
# 2312943    False
# Name: App Name, Length: 2312944, dtype: object

# %%
#7.FIND THE AVERAGE OF  APP RATING
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#7(a).DISPLYING APP RATIMG OF THE EACH APP
data['Rating']
# Out:
# 0          0.0
# 1          4.4
# 2          0.0
# 3          5.0
# 4          0.0
#           ...
# 2312939    4.3
# 2312940    0.0
# 2312941    0.0
# 2312942    3.5
# 2312943    5.0
# Name: Rating, Length: 2312944, dtype: float64

# %%
#7(b).FINDING AVERAGE APP RATING USING MEAN() FUNCTION
data['Rating'].mean()
# Out:
# np.float64(2.203151531771424)

# %%
#8.FIND TOTAL NUMBER OF UNIQUE CATEGORY IN CATEGORY COLUMN
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#8(a).TOTAL NUMBER OF UNIQUE CATEGORY
data['Category'].nunique()
# Out:
# 48

# %%
#9.WHICH CATEGORY GETTING HIGHEST AVERAGE RATING
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#9(a).GROUPING THE CAREGORIES BY USING GROUPBY() METHOD
data.groupby('Category')

# %%
#9(b).CALCULATING MEAN TO FIND THE AVERAGE OF THE CATEGORY
data.groupby('Category')['Rating'].mean()
# Out:
# Category
# Action                     2.705979
# Adventure                  2.814991
# Arcade                     2.450481
# Art & Design               1.952354
# Auto & Vehicles            2.049613
# Beauty                     1.434105
# Board                      2.782275
# Books & Reference          2.467159
# Business                   1.439082
# Card                       3.085160
# Casino                     3.279682
# Casual                     2.425160
# Comics                     2.864906
# Communication              2.122591
# Dating                     2.452001
# Education                  2.246840
# Educational                2.437742
# Entertainment              2.435374
# Events                     1.270809
# Finance                    2.403102
# Food & Drink               1.294563
# Health & Fitness           1.623777
# House & Home               1.485381
# Libraries & Demo           2.087115
# Lifestyle                  1.930376
# Maps & Navigation          2.224805
# ...

# %%
#9(c).FINDING THE HIGHEST AVERAGE CATEGORY IN DECENDIG ORDER
data.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# Role Playing               3.384498
# Casino                     3.279682
# Simulation                 3.210887
# Weather                    3.120295
# Card                       3.085160
# Racing                     2.960385
# Video Players & Editors    2.903842
# Word                       2.902076
# Strategy                   2.878900
# Comics                     2.864906
# Adventure                  2.814991
# Board                      2.782275
# Personalization            2.758754
# Action                     2.705979
# Puzzle                     2.688279
# Music                      2.662008
# Trivia                     2.526178
# Photography                2.519765
# News & Magazines           2.483766
# Books & Reference          2.467159
# Dating                     2.452001
# Arcade                     2.450481
# Educational                2.437742
# Entertainment              2.435374
# Casual                     2.425160
# Parenting                  2.423273
# ...

# %%
#10.TOTAL NUMBER OF APPS HAVING 5 STAR RATING
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#9(a).RETRIVEING THE RATINGS OF THE ALL APPS
data['Rating']
# Out:
# 0          0.0
# 1          4.4
# 2          0.0
# 3          5.0
# 4          0.0
#           ...
# 2312939    4.3
# 2312940    0.0
# 2312941    0.0
# 2312942    3.5
# 2312943    5.0
# Name: Rating, Length: 2312944, dtype: float64

# %%
#9(b).FINDING THE TOTAL NUMBER OF APPS HAVING THE 5 STAR RATING
data['Rating']==5.0
# Out:
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 2312939    False
# 2312940    False
# 2312941    False
# 2312942    False
# 2312943     True
# Name: Rating, Length: 2312944, dtype: bool

# %%
#9(c).FINDING TOTAL NUMBER OF APPS WHICH HAS 5 STAR RATING WITH THE INTERGER NUMBER USING LEN() FUNCTION
len(data[data['Rating']==5.0])
# Out:
# 100122

# %%
#10.FINDING THE TOTAL NUMBER OF FREE AND PAID APPS
#10(a)DISPLYING THE FIRST ROW OF OUR DATASET
data.head(1)
# Out:
#   App Name               App Id   Category  Rating  Rating Count Installs  \
# 0  Gakondo  com.ishakwe.gakondo  Adventure     0.0           0.0      10+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
#
#              Developer Website         Developer Email      Released  \
# 0  https://beniyizibyose.tk/#/  jean21101999@gmail.com  Feb 26, 2020
#
#    Last Updated Content Rating                      Privacy Policy  \
# 0  Feb 26, 2020       Everyone  https://beniyizibyose.tk/projects/
#
#   Ad Supported In App Purchases Editors Choice         Scraped Time
# 0        False            False          False  2021-06-15 20:19:35
#
# [1 rows x 24 columns]

# %%
#10(b).RETRIVING THE PAID AND FREE APPS BY USING COUNTS() FUNCTION
data['Free'].value_counts()
# Out:
# Free
# True     2267876
# False      45068
# Name: count, dtype: int64

# %%
#11.WHICH APP HAS THE MAXIMUM RATINGS
data.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#11(a).RETRIVING THE RATINGS
data['Rating']
# Out:
# 0          0.0
# 1          4.4
# 2          0.0
# 3          5.0
# 4          0.0
#           ...
# 2312939    4.3
# 2312940    0.0
# 2312941    0.0
# 2312942    3.5
# 2312943    5.0
# Name: Rating, Length: 2312944, dtype: float64

# %%
#11(b).FINDING THE MAXIMUM RATINGS BY USING MAX() FUNCTION
data['Rating'].max()
# Out:
# np.float64(5.0)

# %%
#11(c).COMPARING THIS MAXIMUM VALUES WITH OTHER VALUES
data['Rating'].max()==data['Rating']
# Out:
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 2312939    False
# 2312940    False
# 2312941    False
# 2312942    False
# 2312943     True
# Name: Rating, Length: 2312944, dtype: bool

# %%
#12.FIND AVERAGE RATING FREE AND PAID APPS
#RETRIVING THE ROWS
data.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
#12(a).GROUPING THE FREE RATING COLUMNS AND FINDING THE AVERAGE FOR THAT USING MEAN () FUNCTION
data.groupby('Free')['Rating'].mean()
# Out:
# Free
# False    2.363458
# True     2.199950
# Name: Rating, dtype: float64

# %%
#13.DISPLAY TIP 5 APPS HAVING MAXIMUM INSTALLS
#RETRIVING THE FIRST ROW OF THE DATA
data.head(1)
# Out:
#   App Name               App Id   Category  Rating  Rating Count Installs  \
# 0  Gakondo  com.ishakwe.gakondo  Adventure     0.0           0.0      10+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
#
#              Developer Website         Developer Email      Released  \
# 0  https://beniyizibyose.tk/#/  jean21101999@gmail.com  Feb 26, 2020
#
#    Last Updated Content Rating                      Privacy Policy  \
# 0  Feb 26, 2020       Everyone  https://beniyizibyose.tk/projects/
#
#   Ad Supported In App Purchases Editors Choice         Scraped Time
# 0        False            False          False  2021-06-15 20:19:35
#
# [1 rows x 24 columns]

# %%
#13(a).GETTING THE TOTALS INSTALLLS OF ALL THE APPS
data['Installs']
# Out:
# 0               10+
# 1            5,000+
# 2               50+
# 3               10+
# 4              100+
#              ...
# 2312939    100,000+
# 2312940        100+
# 2312941        100+
# 2312942      1,000+
# 2312943        100+
# Name: Installs, Length: 2312944, dtype: object

# %%
#13(b).CHECKING THE DATATYPE
data['Installs'].dtype
# Out:
# dtype('O')

# %%
#13(b)REMOVING THE(,)FROM THE DATA TO CONVERT DATA TYPE
data['Installs'].str.replace(',','')
# Out:
# 0              10+
# 1            5000+
# 2              50+
# 3              10+
# 4             100+
#             ...
# 2312939    100000+
# 2312940       100+
# 2312941       100+
# 2312942      1000+
# 2312943       100+
# Name: Installs, Length: 2312944, dtype: object

# %%
#13(c).ADDING A NEW COLUMN TO THE DATA SET
data['Installs_1']=data['Installs'].str.replace(',','')

# %%
#13(d).CHECKING THE FIRST ROW OF OUR DATASET
data.head(1)
# Out:
#   App Name               App Id   Category  Rating  Rating Count Installs  \
# 0  Gakondo  com.ishakwe.gakondo  Adventure     0.0           0.0      10+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
#
#           Developer Email      Released  Last Updated Content Rating  \
# 0  jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
#
#                        Privacy Policy Ad Supported In App Purchases  \
# 0  https://beniyizibyose.tk/projects/        False            False
#
#   Editors Choice         Scraped Time Installs_1
# 0          False  2021-06-15 20:19:35        10+
#
# [1 rows x 25 columns]

# %%
#13(e).REMOVING THE + SIGH TO CONVERT THE DATA INTO OBJECT DATA TYPE
data['Installs_1']=data['Installs_1'].str.replace('+','')

# %%
#13(f).CHECKING THE FIRST ROW OF OUR DATASET
data.head(1)
# Out:
#   App Name               App Id   Category  Rating  Rating Count Installs  \
# 0  Gakondo  com.ishakwe.gakondo  Adventure     0.0           0.0      10+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
#
#           Developer Email      Released  Last Updated Content Rating  \
# 0  jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
#
#                        Privacy Policy Ad Supported In App Purchases  \
# 0  https://beniyizibyose.tk/projects/        False            False
#
#   Editors Choice         Scraped Time Installs_1
# 0          False  2021-06-15 20:19:35         10
#
# [1 rows x 25 columns]

# %%
#13(g).REPLACING string(Free) INTO 0 TO CONVERT THE DATA TYPE FROM OBJECT TO FLOAT
data['Installs_1']=data['Installs_1'].str.replace('Free','0')

# %%
#13(h).REPLACING NaN TO 0
data['Installs_1']=data['Installs_1'].str.replace('NaN','0')

# %%
data['Installs_1'].astype('float')
# Out:
# 0              10.0
# 1            5000.0
# 2              50.0
# 3              10.0
# 4             100.0
#              ...
# 2312939    100000.0
# 2312940       100.0
# 2312941       100.0
# 2312942      1000.0
# 2312943       100.0
# Name: Installs_1, Length: 2312944, dtype: float64

# %%
#13(i).DISPLAY TOP 5 APPS HAVING MAXIMUM INSTALLS
index=data['Installs_1'].sort_values(ascending=False).head().index

# %%
#13(j).DISPLYING  ROWS BY USING ILOC() FUNCTION
data.iloc[index]
# Out:
#                                  App Name                          App Id  \
# 2222701                          Facebook             com.facebook.katana
# 944254       Google Chrome: Fast & Secure              com.android.chrome
# 1830962                     Google Photos  com.google.android.apps.photos
# 1733042  Google Maps - Navigate & Explore    com.google.android.apps.maps
# 2099458                             Gmail           com.google.android.gm
#
#                Category  Rating  Rating Count        Installs  \
# 2222701          Social     2.3   117850066.0  5,000,000,000+
# 944254    Communication     4.1    31481796.0  5,000,000,000+
# 1830962     Photography     4.5    35369236.0  5,000,000,000+
# 1733042  Travel & Local     3.8    13576045.0  5,000,000,000+
# 2099458   Communication     4.2     9488421.0  5,000,000,000+
#
#          Minimum Installs  Maximum Installs  Free  Price  ...  \
# 2222701      5.000000e+09        6782619635  True    0.0  ...
# ...

# %%
#13(k).DISPLAYING PARTICULAR ROW(APP NAMES) AS WE REQUIRED
data.iloc[index]['App Name']
# Out:
# 2222701                            Facebook
# 944254         Google Chrome: Fast & Secure
# 1830962                       Google Photos
# 1733042    Google Maps - Navigate & Explore
# 2099458                               Gmail
# Name: App Name, dtype: object

# %%
#14.Selecting top 10 categories and their counts
top_10_categories = data.head(10)

#14(a). Extracting category names and counts
categories = top_10_categories['Category']
counts = top_10_categories['Rating Count']

# 14(b).Define colors for each category
colors = ['skyblue', 'steelblue', 'deepskyblue', 'dodgerblue', 'royalblue', 
          'cornflowerblue', 'lightskyblue', 'lightsteelblue', 'mediumblue', 'darkblue']

#14(c). Create a bar plot with multiple colors
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, counts)

plt.title('Top 10 Categories')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.xticks(rotation=90)  
plt.show()

# %%
The provided code snippet effectively visualizes the top 10 categories and their respective rating counts using a bar plot. 
It ensures each category is visually distinguishable by assigning unique colors to each bar. 
This type of visualization is useful for quickly understanding which categories have the highest rating counts relative to others in the dataset.
by considering above diagram we can conclude that the personalisation category having the highest rating where ascommunication having the less rating

# %%
# Check this top 10 highest rating category
import matplotlib.pyplot as plt
top_10_categories = data.head(10)


plt.figure(figsize=(10, 6))
plt.bar(top_10_categories['Category'],top_10_categories['Rating'], color=colors)

plt.xlabel('Category')

plt.ylabel('Rating')

plt.title('Top 10 Category with highest rating')
plt.show()

# %%
1.Top 10 Categories: The plot visualizes the ratings of the top 10 categories based on the data provided (data.head(10)).
2.Rating Distribution: We can observe how the ratings are distributed across these top categories. 
This could provide insights into which categories are performing well relative to others.
here communication category has highest rating whare as lifestyle category has less

# %%
# Display the top-ranked free and paid app categories using a bar plot
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Highest Free and paid app category')
sns.countplot(x='Category', data=top_10_categories, hue='Free')
# Out:
# <Axes: title={'center': 'Highest Free and paid app category'}, xlabel='Category', ylabel='Count'>

# %%
Distribution Across Categories: You can see which categories have the highest number of apps overall.
Comparison of Free vs Paid Apps: You can compare how the number of free apps varies across categories compared to paid apps.
Insights into App Pricing Strategies: Depending on the distribution, you might infer insights into how different categories monetize their apps
(e.g., more paid apps in certain categories).
Overall, the plot helps in understanding the distribution of apps across categories and the prevalence of free versus paid models within those categories.

# %%
# Create a pie plot show the persentage of insatll free and paid apps category
plt.figure(figsize=(6,6))
plt.pie(data['Free'].value_counts(), labels=['Free', 'Paid'], autopct='%1.1f%%')
plt.title('Persentage of insatll free and paid apps category')
plt.show()

# %%
Percentage of Free vs Paid Apps: You can visually see the proportion of free apps versus paid apps in the dataset.
Relative Distribution: It provides a quick understanding of whether the majority of apps in the dataset are free or paid.
overall 98.1% apps atre free whereas only 1.9% are paid
